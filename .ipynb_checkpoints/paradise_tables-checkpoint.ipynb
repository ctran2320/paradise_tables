# %%
import pandas as pd

import mysql.connector
import os
os.chdir('C:\\Users\\ctran\\Documents\\DSC_projects\\paradise_tables')
from sqlalchemy import create_engine

engine = create_engine('mysql+mysqlconnector://root:Left4dead2!2320@localhost/paradise_tables')
labor = pd.read_sql('SELECT * FROM labor', engine)

# %%
df = pd.read_csv('Operation Expenses - Ingredients.csv')
for i in df.values:
    s ='('  + str(i[0]) + ', ' + "'" + str(i[1])  + ", " + "'" + str(i[2])  + "'" + ', ' + str(i[3]) + ', ' + str(i[4])+ ', ' + "'" +str(i[5]) + "'"+ ')'+ ','
    print(s)
# Out:
# (10, '0001', 'Watermelon', 7.23, 1, 'Good Fortune Supermarket'),
# (10, '0002', 'Green Grapes', 4.93, 1, 'Good Fortune Supermarket'),
# (10, '0003', 'Red Grapes', 4.88, 1, 'Good Fortune Supermarket'),
# (10, '0004', 'Honeydew Melon', 8.18, 1, 'Good Fortune Supermarket'),
# (10, '0005', 'Strawberries', 3.99, 1, 'Good Fortune Supermarket'),
# (10, '0006', 'Blueberries', 6.99, 1, 'Good Fortune Supermarket'),
# (10, '1000', 'Reusable Bags', 0.46, 2, 'Good Fortune Supermarket'),
# (13, '0111', 'Heavy Cream', 9.99, 1, 'Smart & Final'),
# (13, '0112', 'Butter', 4.49, 1, 'Smart & Final'),
# (13, '0010', 'Pillsburry Moist Chocolate Cake', 1.99, 1, 'Smart & Final'),
# (13, '0011', 'Twix Funsize', 6.49, 1, 'Smart & Final'),
# (13, '0012', 'Reeses Peanut Butter Cups', 4.39, 1, 'Smart & Final'),
# (13, '0013', 'M&M Milk Chocolates', 4.49, 1, 'Smart & Final'),
# (13, '0014', 'Kit Kat Minis', 4.39, 1, 'Smart & Final'),
# (13, '0048', 'Torani Puremade Caramel', 4.99, 1, 'Smart & Final'),
# ...

# %%
# df = pd.read_csv('Operation Expenses - Labor.csv')
# for i in df.values:
#     s ='('  +  "'"+ str(i[0]) + "'"+ ', '  +"'"+ str(i[1])  + ", " + "'" + str(i[2])  + "'" + ', ' + str(i[3]) + ', ' + str(i[4])+ ', ' + "'" +str(i[5]) + "'"+  ', ' +"'"+ str(pd.to_datetime(i[6]).strftime('%Y-%m-%d')) +"'"+ ')' +','
#     print(s)

# %%
# df = pd.read_csv('Operation Expenses - Order Details.csv')
# for i in df.values:
#     s ='('  +  "'"+ str(i[0]) + "'"+ ', '  +"'"+ str(i[1])  + ", " + "'" + str(i[2])  + "'" + ', ' + str(i[3])  + ')' +','
#     print(s)

# %%
# df = pd.read_csv('Operation Expenses - Orders.csv')
# for i in df.values:
#     s ='('  +  "'"+ str(i[0]) + "'"+ ', ' + str(i[2])  + ", " +  "'" +str(pd.to_datetime(i[3]).strftime('%Y-%m-%d'))  + "'" + ', ' +  "'" +str(i[4]) + "'" + ',' + str(i[5]) + ')' +','
#     print(s)

# %%
# df = pd.read_csv('Operation Expenses - Overhead.csv')
# for i in df.values:
#     try:
#         s ='('  +  "'"+ str(i[0]) + ', ' + "'"+str(i[1])  + "'"+", " + str(i[2])+ ', ' + str(i[3])+ ', ' +  "'" +str(pd.to_datetime(i[4]).strftime('%Y-%m-%d')) +"'" +  ')' +','
#         print(s)
#     except:
#         3

# %%
# df = pd.read_csv('Operation Expenses - Personal Labor.csv')
# for i in df.values:
#     s ='('  +  "'"+ str(i[0]) + "'"+ ', '  +"'"+ str(i[1])  + ", " + "'" + str(i[2])  + "'" + ', ' + str(i[3]) +  ')' +','
#     print(s)

# %%
# df = pd.read_csv('Operation Expenses - Supplies Used.csv')
# for i in df.values:
#     s ='('  +  "'"+ str(i[0]) +  ', '  +"'"+ str(i[1])  + "'"+", " + str(i[2])   + ', ' +  "'"+str(i[3]) +  "'"+ ')' +','
#     print(s)

# %%
pd.read_sql('SELECT SUM(Revenue)  as TotalRevenue FROM `paradise_tables`.`orders`', engine)
# Out:
#    TotalRevenue
# 0   9324.799992

# %%
pd.read_sql('SELECT count(*) as TotalOrders FROM `paradise_tables`.`orders` WHERE Revenue > 0', engine)
# Out:
#    TotalOrders
# 0           43

# %%
pd.read_sql('SELECT date_format(date, "%Y-%m") as date ,sum(`Revenue`) as revenue FROM `paradise_tables`.`orders` GROUP BY MONTH(`Date`)',engine)
# Out:
#       date      revenue
# 0  2022-07   350.000000
# 1  2022-08   227.000000
# 2  2022-09   979.399994
# 3  2022-10   714.599991
# 4  2022-11  1147.400009
# 5  2022-12  1805.699982
# 6  2023-01   990.800003
# 7  2023-02   725.900013
# 8  2023-03   889.000000
# 9  2023-04  1495.000000

# %%
pd.read_sql('SELECT count(*) / count(distinct date_format(date, "%Y-%m")) as avg_orders_per_month FROM `paradise_tables`.`orders` WHERE `Revenue` > 0',engine)
# Out:
#    avg_orders_per_month
# 0                   4.3

# %%
query_5 = '''SELECT sum(Quantity) as tot_quant, ItemID, ItemDescription 
            FROM `paradise_tables`.`order_details` as od 
            JOIN `paradise_tables`.`orders` as o 
            ON od.OrderID = o.OrderID 
            WHERE Revenue > 0 
            GROUP BY ItemID 
            ORDER BY tot_quant DESC'''
pd.read_sql(query_5 ,engine)
# Out:
#     tot_quant ItemID                 ItemDescription
# 0       466.0    110         Assorted Fruit Pastries
# 1       308.0     30           Mango Cheesecake Cups
# 2       229.0    150         Nutella Cheesecake Cups
# 3       203.0     10          Matcha Cheesecake Cups
# 4       198.0     20      Strawberry Cheesecake Cups
# 5       193.0     60             Banana Pudding Cups
# 6       183.0     50           Tres Leches Cake Cups
# 7       170.0    210  Chocolate Covered Strawberries
# 8       120.0    170       Earl Grey Cheesecake Cups
# 9       119.0    120              Cheesecake Cookies
# 10      107.0    160   Cookie Butter Cheesecake Cups
# 11       98.0     40       Blueberry Cheesecake Cups
# 12       91.0    100               Mango Mousse Cups
# 13       77.0     90          Strawberry Mousse Cups
# 14       71.0     80           Chocolate Mousse Cups
# 15       24.0    240          Chocolate Chip Cookies
# 16       24.0    250                   Sugar Cookies
# ...

# %%
query_6 = '''
        SELECT AVG(TotalQuantity)
            FROM
            (SELECT SUM(Quantity) as TotalQuantity, od.OrderID
            FROM `paradise_tables`.`order_details` as od
            JOIN `paradise_tables`.`orders` as o
            ON o.OrderID = od.OrderID
            WHERE Revenue > 0
            GROUP BY OrderID) as a
'''
pd.read_sql(query_6, engine)
# Out:
#    AVG(TotalQuantity)
# 0             63.3721

# %%
query_7 = '''
            SELECT o.Date, 
                    o.OrderID, 
                    o.Revenue, 
                    sub.supply_cost, 
                    ingredients.ingredient_cost, 
                    labor.compensation,
                    sub.supply_cost + ingredients.ingredient_cost as total_cost,
                    o.Revenue - (sub.supply_cost + ingredients.ingredient_cost) as profit
                FROM `paradise_tables`.`orders` as o
                JOIN (
                    SELECT sum(Quantity * avg_supply_price) as supply_cost, 
                            s.OrderID,
                            s.SupplyID, 
                            s.SupplyDescription
                        FROM `paradise_tables`.`supplies_used` as s
                        LEFT JOIN(SELECT AVG(Cost/Quantity) as avg_supply_price, SupplyID, SupplyDescription 
                        FROM `paradise_tables`.`overhead` 
                        GROUP BY SupplyID) as a
                        ON s.SupplyID = a.SupplyID  
                        GROUP BY s.OrderID) as sub
                ON o.OrderID = sub.OrderID
                JOIN (
                    SELECT sum(Cost) as ingredient_cost, 
                        OrderID
                    FROM `paradise_tables`.`ingredients` as i
                    GROUP BY i.OrderID) as ingredients
                ON o.OrderID = ingredients.OrderID 
                LEFT JOIN (
                    SELECT sum(Compensation) as compensation, 
                    l.OrderID
                    FROM `paradise_tables`.`labor` as l
                    GROUP BY l.OrderID
                ) as labor
                ON o.OrderID = labor.OrderID'''
pd.read_sql(query_7,engine)
# Out:
#          Date  OrderID  Revenue  supply_cost  ingredient_cost  compensation  \
# 0  2022-10-01       10    135.0     4.740200        36.660000           NaN
# 1  2022-10-02       13      0.0     3.855250        61.999999           NaN
# 2  2022-10-08       11    236.2    24.735500        26.159999           NaN
# 3  2022-10-08       12    120.0    15.027400        12.470000           NaN
# 4  2022-10-22       16      0.0    44.060001        88.759998           NaN
# 5  2022-11-11       17    120.0    15.853525        70.670000           NaN
# 6  2022-11-12       19     64.8     6.871500         7.450000           NaN
# 7  2022-11-12       18     62.4     8.615200        29.030000           NaN
# 8  2022-11-13       20    264.0    20.352000        17.420000           NaN
# 9  2022-11-19       21     62.4     8.615200         4.990000           NaN
# 10 2022-11-26       22    196.8    24.101900        55.900000           NaN
# ...

# %%
query_8 = '''
            SELECT sum(Hours) as hours, LaborID, LaborDescription
            FROM `paradise_tables`.`personal_labor`
            GROUP BY LaborID   
'''
pd.read_sql(query_8,engine)
# Out:
#      hours LaborID    LaborDescription
# 0   20.430     100  Buying Ingredients
# 1  150.330     200     Making Desserts
# 2    6.866     300            Delivery
# 3    4.000     400              Set Up

# %%
query_9 = '''
            SELECT avg(Cost) as avg_cost, sum(Quantity) as qty,count(*) as cnt, IngredientDescription, Location
            FROM `paradise_tables`.`ingredients` 
            GROUP BY Location, IngredientID
            HAVING count(*) > 5
            ORDER BY cnt DESC, qty ASC
'''
pd.read_sql(query_9,engine)
# Out:
#     avg_cost   qty  cnt    IngredientDescription                  Location
# 0  14.111250  22.0   16              Heavy Cream             Smart & Final
# 1  34.489090  11.0   11  No Ingredients Recorded                       nan
# 2   4.691000  11.0   10              Blueberries             Smart & Final
# 3  23.657777  21.0    9             Cream Cheese                    Costco
# 4   2.227500   8.0    8      2% Reduced Fat Milk             Smart & Final
# 5   1.404286   7.0    7          Evaporated Milk             Smart & Final
# 6   3.935714  16.0    7                  Mangoes  Good Fortune Supermarket
# 7  11.265714  18.0    7             Strawberries             Smart & Final
# 8   8.191667  16.0    6             Strawberries                      Aldi

# %%
a = pd.read_sql('Select * FROM `paradise_tables`.`ingredients`',engine)
b=a.groupby(['Location','IngredientDescription']).mean().Cost.reset_index()
c = a.groupby(['Location','IngredientDescription']).count().OrderID.reset_index()
c[c.OrderID>5]
# Out:
#                      Location    IngredientDescription  OrderID
# 8                        Aldi             Strawberries        6
# 13                     Costco             Cream Cheese        9
# 26   Good Fortune Supermarket                  Mangoes        7
# 46              Smart & Final      2% Reduced Fat Milk       12
# 51              Smart & Final              Blueberries       10
# 63              Smart & Final          Evaporated Milk        6
# 67              Smart & Final              Heavy Cream       16
# 84              Smart & Final             Strawberries        7
# 101                       nan  No Ingredients Recorded       11

# %%
# Out:
#      OrderID IngredientID IngredientDescription  Cost  Quantity       Location
# 111       28         0015   2% Reduced Fat Milk  1.79         1  Smart & Final
# 124       30         0015   2% Reduced Fat Milk  1.99         1  Smart & Final
# 151       37         0015   2% Reduced Fat Milk  2.69         1  Smart & Final
# 161       39         0015   2% Reduced Fat Milk  1.79         1  Smart & Final
# 172       41         0015   2% Reduced Fat Milk  2.59         1  Smart & Final
# 199       45         0015   2% Reduced Fat Milk  2.59         1  Smart & Final
# 213       47         0015   2% Reduced Fat Milk  2.59         1  Smart & Final
# 225       48         0015   2% Reduced Fat Milk  1.79         1  Smart & Final
